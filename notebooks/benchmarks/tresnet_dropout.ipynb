# %%
from tresnet.benchmark_utils import benchmarks_from_dir

# %%
tgtdir = "logs/benchmarks/tresnet_dropout/"
results, metrics = benchmarks_from_dir(tgtdir)
# Out:
# Extracting 1351 files that look like ihdp/poisson/000034/tresnet/srf_estimates.csv
# 100%|██████████| 1351/1351 [00:36<00:00, 37.40it/s]

# %%
metrics
# Out:
#                                   train_mse  test_mse  train_bias2
# dataset family    experiment
# ihdp    bernoulli aipw             0.011603  0.009526     0.011603  \
#                   ipw_classifier   0.001290  0.001124     0.001290
#                   outcome          0.003586  0.003407     0.003586
#                   tresnet          0.004302  0.003920     0.004302
#                   tresnet_clever   0.002289  0.002113     0.002289
#         gaussian  aipw             0.195656  0.176285     0.195656
#                   ipw_classifier   0.016762  0.014551     0.016762
#                   outcome          0.156816  0.173815     0.156816
#                   tresnet          0.108708  0.116069     0.108708
#                   tresnet_clever   0.137916  0.153010     0.137916
#         poisson   aipw             5.247466  0.685115     5.247466
#                   ipw_classifier   0.010142  0.131413     0.010142
#                   outcome          0.095349  0.956000     0.095349
#                   tresnet          2.413429  0.004691     2.413429
#                   tresnet_clever   0.223188  0.926322     0.223188
# news    bernoulli aipw             0.000467  0.001004     0.000467
#         gaussian  aipw             0.028256  0.031086     0.028256
#
#                                   test_bias2  train_variance  test_variance
# dataset family    experiment
# ihdp    bernoulli aipw              0.009526        0.002500       0.003359
#                   ipw_classifier    0.001124        0.000716       0.002879
#                   outcome           0.003407        0.001477       0.001647
#                   tresnet           0.003920        0.001225       0.001363
#                   tresnet_clever    0.002113        0.000576       0.000748
#         gaussian  aipw              0.176285        0.053909       0.057832
#                   ipw_classifier    0.014551        0.004268       0.016214
#                   outcome           0.173815        0.041677       0.040671
#                   tresnet           0.116069        0.021119       0.016559
#                   tresnet_clever    0.153010        0.035723       0.033501
#         poisson   aipw              0.685115       33.597905       7.735366
#                   ipw_classifier    0.131413        1.317405       2.479645
#                   outcome           0.956000        3.239602       0.547820
#                   tresnet           0.004691      539.763979       0.901690
#                   tresnet_clever    0.926322        2.621800       0.543682
# news    bernoulli aipw              0.001004        0.000570       0.000869
#         gaussian  aipw              0.031086        5.469092       0.080093
