# %%
from tresnet.benchmark_utils import benchmarks_from_dir

# %%
tgtdir = "logs/benchmarks/tresnet_splines/"
benchmarks = benchmarks_from_dir(tgtdir)
# Out:
# Extracting 533 files that look like tcga-1/poisson/000014/tresnet/srf_estimates.csv
# 100%|██████████| 533/533 [00:14<00:00, 35.90it/s]

# %%
benchmarks["metrics"]
# Out:
#                                              train_mse      test_mse
# dataset family    experiment
# ihdp    bernoulli tresnet                 7.945709e-03  8.452327e-03  \
#                   tresnet_clever          4.893675e-03  5.462631e-03
#                   tresnet_clever_splines  4.608699e-03  5.130662e-03
#         gaussian  tresnet                 2.201789e-01  2.185406e-01
#                   tresnet_clever          1.489975e-01  1.522801e-01
#                   tresnet_clever_splines  1.783502e-01  1.815707e-01
#         poisson   tresnet                 9.723285e-01  9.572079e-01
#                   tresnet_clever          1.029306e+00  1.175638e+00
#                   tresnet_clever_splines  8.689748e-01  9.878450e-01
# news    bernoulli tresnet                 7.852918e-04  6.924834e-04
#                   tresnet_clever          1.620492e-03  1.463474e-03
#                   tresnet_clever_splines  7.466682e-03  6.930996e-03
#         gaussian  tresnet                 1.910979e-02  1.483830e-02
#                   tresnet_clever          6.095033e-02  5.859686e-02
#                   tresnet_clever_splines  1.790740e-02  1.675860e-02
#         poisson   tresnet                 4.495053e+07  2.087460e+02
#                   tresnet_clever          2.692657e+09  2.563448e+02
#                   tresnet_clever_splines  2.640527e+36  3.362244e+11
# tcga-1  bernoulli tresnet                 1.306717e-03  1.211519e-03
#                   tresnet_clever          9.311085e-04  8.247920e-04
#         gaussian  tresnet                 4.152533e-02  3.529631e-02
#                   tresnet_clever          2.940623e-02  2.461057e-02
#         poisson   tresnet                 1.258704e-02  7.822369e-03
#                   tresnet_clever          3.971986e-03  3.763690e-03
#
#                                            train_bias2    test_bias2
# dataset family    experiment
# ihdp    bernoulli tresnet                 7.945709e-03  8.452327e-03  \
#                   tresnet_clever          4.893675e-03  5.462631e-03
#                   tresnet_clever_splines  4.608699e-03  5.130662e-03
#         gaussian  tresnet                 2.201789e-01  2.185406e-01
#                   tresnet_clever          1.489975e-01  1.522801e-01
#                   tresnet_clever_splines  1.783502e-01  1.815707e-01
#         poisson   tresnet                 9.723285e-01  9.572079e-01
#                   tresnet_clever          1.029306e+00  1.175638e+00
#                   tresnet_clever_splines  8.689748e-01  9.878450e-01
# news    bernoulli tresnet                 7.852918e-04  6.924834e-04
#                   tresnet_clever          1.620492e-03  1.463474e-03
#                   tresnet_clever_splines  7.466682e-03  6.930996e-03
#         gaussian  tresnet                 1.910979e-02  1.483830e-02
#                   tresnet_clever          6.095033e-02  5.859686e-02
#                   tresnet_clever_splines  1.790740e-02  1.675860e-02
#         poisson   tresnet                 4.495053e+07  2.087460e+02
#                   tresnet_clever          2.692657e+09  2.563448e+02
#                   tresnet_clever_splines  2.640527e+36  3.362244e+11
# tcga-1  bernoulli tresnet                 1.306717e-03  1.211519e-03
#                   tresnet_clever          9.311085e-04  8.247920e-04
#         gaussian  tresnet                 4.152533e-02  3.529631e-02
#                   tresnet_clever          2.940623e-02  2.461057e-02
#         poisson   tresnet                 1.258704e-02  7.822369e-03
#                   tresnet_clever          3.971986e-03  3.763690e-03
#
#                                           train_variance  test_variance
# dataset family    experiment
# ihdp    bernoulli tresnet                   3.405271e-04   3.105634e-04
#                   tresnet_clever            5.531063e-04   5.612149e-04
#                   tresnet_clever_splines    2.389020e-02   2.361425e-02
#         gaussian  tresnet                   4.043697e-03   3.648557e-03
#                   tresnet_clever            6.851219e-03   6.349681e-03
#                   tresnet_clever_splines    3.139446e-01   3.184164e-01
#         poisson   tresnet                   1.266122e-01   7.325638e-01
#                   tresnet_clever            2.276211e-01   5.056578e-01
#                   tresnet_clever_splines    1.726882e+00   1.921509e+00
# news    bernoulli tresnet                   1.651115e-04   1.688444e-04
#                   tresnet_clever            4.560720e-04   4.421377e-04
#                   tresnet_clever_splines    4.168849e-02   4.139949e-02
#         gaussian  tresnet                   5.138190e-03   5.645386e-03
#                   tresnet_clever            5.821118e-03   6.014525e-03
#                   tresnet_clever_splines    8.378199e-01   8.767637e-01
#         poisson   tresnet                   3.112497e+09   2.833680e-02
#                   tresnet_clever            5.067032e+10   3.900907e-02
#                   tresnet_clever_splines    4.224844e+37   5.345448e+12
# tcga-1  bernoulli tresnet                   6.129018e-04   9.087932e-04
#                   tresnet_clever            6.165318e-04   9.908068e-04
#         gaussian  tresnet                   1.732506e-02   2.953928e-02
#                   tresnet_clever            4.294379e-02   5.578341e-02
#         poisson   tresnet                   1.190790e-01   1.134691e-01
#                   tresnet_clever            1.794393e-01   1.995068e-01

# %%
benchmarks["auc"]
# Out:
#                                           train_rank  train_rank_norm
# dataset family    experiment
# ihdp    bernoulli tresnet                  29.225806         0.339835  \
#                   tresnet_clever           44.677419         0.519505
#                   tresnet_clever_splines   22.096774         0.256939
#         gaussian  tresnet                  24.000000         0.292683
#                   tresnet_clever           42.096774         0.513375
#                   tresnet_clever_splines   29.903226         0.364673
#         poisson   tresnet                  37.032258         0.514337
#                   tresnet_clever           33.741935         0.468638
#                   tresnet_clever_splines   25.225806         0.350358
# news    bernoulli tresnet                  30.444444         0.543651
#                   tresnet_clever           19.352941         0.345588
#                   tresnet_clever_splines    9.250000         0.165179
#         gaussian  tresnet                  36.033333         0.571958
#                   tresnet_clever           17.263158         0.274018
#                   tresnet_clever_splines   10.250000         0.162698
#         poisson   tresnet                  25.850000         0.538542
#                   tresnet_clever           16.411765         0.341912
#                   tresnet_clever_splines   11.625000         0.242188
# tcga-1  bernoulli tresnet                  11.266667         0.512121
#                   tresnet_clever           11.785714         0.535714
#         gaussian  tresnet                   9.666667         0.371795
#                   tresnet_clever           13.357143         0.513736
#         poisson   tresnet                   8.142857         0.542857
#                   tresnet_clever            4.500000         0.300000
#
#                                           test_rank  test_rank_norm
# dataset family    experiment
# ihdp    bernoulli tresnet                 29.064516        0.337959
#                   tresnet_clever          45.419355        0.528132
#                   tresnet_clever_splines  21.516129        0.250188
#         gaussian  tresnet                 24.548387        0.299371
#                   tresnet_clever          41.967742        0.511802
#                   tresnet_clever_splines  29.483871        0.359559
#         poisson   tresnet                 41.000000        0.525641
#                   tresnet_clever          28.870968        0.370141
#                   tresnet_clever_splines  26.129032        0.334988
# news    bernoulli tresnet                 30.444444        0.543651
#                   tresnet_clever          19.352941        0.345588
#                   tresnet_clever_splines   9.250000        0.165179
#         gaussian  tresnet                 36.033333        0.571958
#                   tresnet_clever          17.263158        0.274018
#                   tresnet_clever_splines  10.250000        0.162698
#         poisson   tresnet                 17.650000        0.392222
#                   tresnet_clever          23.588235        0.524183
#                   tresnet_clever_splines  13.250000        0.294444
# tcga-1  bernoulli tresnet                  9.800000        0.426087
#                   tresnet_clever          13.214286        0.574534
#         gaussian  tresnet                 10.200000        0.408000
#                   tresnet_clever          12.857143        0.514286
#         poisson   tresnet                  8.142857        0.542857
#                   tresnet_clever           4.500000        0.300000

# %%
benchmarks["auc"].reset_index().groupby(["family", "experiment"])[["train_rank", "test_rank"]].mean()
# Out:
#                         train_rank  test_rank
# experiment
# tresnet                  23.518004  22.987060
# tresnet_clever           22.576317  23.003759
# tresnet_clever_splines   18.058468  18.313172
