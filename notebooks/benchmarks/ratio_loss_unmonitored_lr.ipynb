# %%
from tresnet.benchmark_utils import benchmarks_from_dir

# %%
tgtdir = "logs/benchmarks/ratio_loss_unmonitored_lr/"
results, metrics = benchmarks_from_dir(tgtdir)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 tgtdir = "logs/benchmarks/ratio_loss_unmonitored_lr/"
# ----> 2 results, metrics = benchmarks_from_dir(tgtdir)
#
# File /net/rcstorenfs02/ifs/rc_labs/dominici_lab/lab/projects/mauricio-tresnet/tresnet/benchmark_utils.py:25, in benchmarks_from_dir(root_dir)
#      14 """Load results from an experiment directory. It recursively searches
#      15 for all `srf_estimates.csv` files and loads them into a DataFrame.
#      16 It uses the corresponding `args.yaml` file to extract the experiment
#    (...)
#      22              grouped by dataset, glm_family and experiment
#      23 """
#      24 files = glob("**/srf_estimates.csv", root_dir=root_dir, recursive=True)
# ---> 25 logger.warning(f"Extracting {len(files)} files that look like {files[0]}")
#      27 results = []
#      29 for f in tqdm(files):
#
# IndexError: list index out of range

# %%
metrics
# Out:
#                                       train_mse      test_mse  train_bias2
# family    experiment
# bernoulli ipw_classifier               0.001667  1.212928e-03     0.001667  \
#           ipw_classifier_unmonitored   0.001474  5.496313e-04     0.001474
#           ipw_hybrid                   0.000072  1.632812e-04     0.000072
#           ipw_multips                  0.001068  9.903444e-04     0.001068
#           ipw_ps                       0.000636  3.345913e-07     0.000636
#           ipw_ps_unmonitored           0.003623  2.543466e-03     0.003623
# gaussian  ipw_classifier               0.017725  1.173571e-02     0.017725
#           ipw_classifier_unmonitored   0.016951  1.158053e-02     0.016951
#           ipw_hybrid                   0.015681  1.966502e-02     0.015681
#           ipw_multips                  0.003798  1.033560e-01     0.003798
#           ipw_ps                       0.022902  1.380481e-02     0.022902
#           ipw_ps_unmonitored           0.038136  2.866890e-02     0.038136
# poisson   ipw_classifier               0.039999  7.979178e-02     0.039999
#           ipw_classifier_unmonitored   0.061817  7.867052e-02     0.061817
#           ipw_hybrid                   6.454130  4.273050e+00     6.454130
#           ipw_multips                 10.596724  4.058701e+02    10.596724
#           ipw_ps                       0.017184  3.239064e-01     0.017184
#
#                                         test_bias2  train_variance
# family    experiment
# bernoulli ipw_classifier              1.212928e-03        0.000733  \
#           ipw_classifier_unmonitored  5.496313e-04        0.000857
#           ipw_hybrid                  1.632812e-04        0.008453
#           ipw_multips                 9.903444e-04        0.000399
#           ipw_ps                      3.345913e-07        0.012349
#           ipw_ps_unmonitored          2.543466e-03        0.018383
# gaussian  ipw_classifier              1.173571e-02        0.004301
#           ipw_classifier_unmonitored  1.158053e-02        0.004860
#           ipw_hybrid                  1.966502e-02        0.096087
#           ipw_multips                 1.033560e-01        0.005306
#           ipw_ps                      1.380481e-02        0.110093
#           ipw_ps_unmonitored          2.866890e-02        0.139537
# poisson   ipw_classifier              7.979178e-02        1.314445
#           ipw_classifier_unmonitored  7.867052e-02        1.297397
#           ipw_hybrid                  4.273050e+00       10.595805
#           ipw_multips                 4.058701e+02        7.872695
#           ipw_ps                      3.239064e-01        6.468589
#
#                                       test_variance
# family    experiment
# bernoulli ipw_classifier                   0.003356
#           ipw_classifier_unmonitored       0.002958
#           ipw_hybrid                       0.024480
#           ipw_multips                      0.054255
#           ipw_ps                           0.043542
#           ipw_ps_unmonitored               0.109384
# gaussian  ipw_classifier                   0.018834
#           ipw_classifier_unmonitored       0.013303
#           ipw_hybrid                       0.223314
#           ipw_multips                      1.034262
#           ipw_ps                           0.411809
#           ipw_ps_unmonitored               0.487279
# poisson   ipw_classifier                   1.832216
#           ipw_classifier_unmonitored       2.211088
#           ipw_hybrid                      28.112313
#           ipw_multips                   1983.179998
#           ipw_ps                          61.710035
