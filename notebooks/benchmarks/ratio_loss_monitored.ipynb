# %%
from tresnet.benchmark_utils import benchmarks_from_dir

# %%
tgtdir = "logs/benchmarks/ratio_loss_monitored/"
results, metrics = benchmarks_from_dir(tgtdir)
# Out:
# Extracting 668 files that look like ihdp/poisson/000034/ipw_multips/srf_estimates.csv
# 100%|██████████| 668/668 [00:14<00:00, 46.52it/s]

# %%
metrics
# Out:
#                                               train_mse      test_mse
# dataset family    experiment
# ihdp    bernoulli ipw_classifier               0.001667  1.212928e-03  \
#                   ipw_classifier_unmonitored   0.001689  4.595997e-04
#                   ipw_hybrid                   0.000072  1.632812e-04
#                   ipw_multips                  0.001083  1.102208e-03
#                   ipw_ps                       0.000636  3.345913e-07
#         gaussian  ipw_classifier               0.017725  1.173571e-02
#                   ipw_classifier_unmonitored   0.016505  1.139757e-02
#                   ipw_hybrid                   0.015681  1.966502e-02
#                   ipw_multips                  0.003754  9.817353e-02
#                   ipw_ps                       0.022902  1.380481e-02
#                   ipw_ps_unmonitored           0.094903  3.505359e-02
#         poisson   ipw_classifier               0.039999  7.979178e-02
#                   ipw_classifier_unmonitored   0.067624  1.281626e-02
#                   ipw_hybrid                   6.454130  4.273050e+00
#                   ipw_multips                 10.943720  3.187176e+02
#                   ipw_ps                       0.017184  3.239064e-01
#
#                                               train_bias2    test_bias2
# dataset family    experiment
# ihdp    bernoulli ipw_classifier                 0.001667  1.212928e-03  \
#                   ipw_classifier_unmonitored     0.001689  4.595997e-04
#                   ipw_hybrid                     0.000072  1.632812e-04
#                   ipw_multips                    0.001083  1.102208e-03
#                   ipw_ps                         0.000636  3.345913e-07
#         gaussian  ipw_classifier                 0.017725  1.173571e-02
#                   ipw_classifier_unmonitored     0.016505  1.139757e-02
#                   ipw_hybrid                     0.015681  1.966502e-02
#                   ipw_multips                    0.003754  9.817353e-02
#                   ipw_ps                         0.022902  1.380481e-02
#                   ipw_ps_unmonitored             0.094903  3.505359e-02
#         poisson   ipw_classifier                 0.039999  7.979178e-02
#                   ipw_classifier_unmonitored     0.067624  1.281626e-02
#                   ipw_hybrid                     6.454130  4.273050e+00
#                   ipw_multips                   10.943720  3.187176e+02
#                   ipw_ps                         0.017184  3.239064e-01
#
#                                               train_variance  test_variance
# dataset family    experiment
# ihdp    bernoulli ipw_classifier                    0.000733       0.003356
#                   ipw_classifier_unmonitored        0.000869       0.003470
#                   ipw_hybrid                        0.008453       0.024480
#                   ipw_multips                       0.000389       0.048890
#                   ipw_ps                            0.012349       0.043542
#         gaussian  ipw_classifier                    0.004301       0.018834
#                   ipw_classifier_unmonitored        0.004899       0.013771
#                   ipw_hybrid                        0.096087       0.223314
#                   ipw_multips                       0.005287       1.015945
#                   ipw_ps                            0.110093       0.411809
#                   ipw_ps_unmonitored                0.190269       0.319673
#         poisson   ipw_classifier                    1.314445       1.832216
#                   ipw_classifier_unmonitored        1.285335       2.401416
#                   ipw_hybrid                       10.595805      28.112313
#                   ipw_multips                       7.452422    1887.521513
#                   ipw_ps                            6.468589      61.710035
