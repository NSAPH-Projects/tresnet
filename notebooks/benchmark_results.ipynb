# %%
import os
import yaml
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# rdir="results/tres_ratios"
rdir="results/benchmarks"

datasets = [d for d in os.listdir(f"../{rdir}") if not d.startswith(".")]

results = []
curves = []
# for part in ("train", "test"):

for dset in datasets:
    dirs =  [d for d in os.listdir(f"../{rdir}/{dset}") if not d.startswith(".")]

    for dir in dirs:
        runs = [d for d in os.listdir(f"../{rdir}/{dset}/{dir}") if not d.startswith(".")] 
        for seed in runs:
            try:
                exp_dir = f"../{rdir}/{dset}/{dir}/{seed}"
                for part in ("test", "train"):
                    with open(f"{exp_dir}/metrics_{part}.yaml", 'r') as io:
                        metrics = yaml.safe_load(io)
                    metrics['seed'] = int(seed)
                    metrics['dataset'] = dset
                    metrics['dir'] = dir
                    metrics["part"] = part
                    results.append(metrics)

                with open(f"{exp_dir}/config.yaml", 'r') as io:
                    cfg = yaml.safe_load(io)

                curve = pd.read_csv(f"{exp_dir}/curve.csv")
                curve['seed'] = int(seed)
                curve['dir'] = dir
                curve['dataset'] = dset
                curves.append(curve)
            except:
                pass

results = pd.DataFrame(results)
curves = pd.concat(curves)

pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)
# results.groupby(['part', 'dataset', 'dir']).mean().reset_index()

# first term just removes the few divergences
agg = results[results.aipw_curve_rmse < 10].groupby(['part', 'dataset', 'dir']).agg(lambda x: f"{x.mean():.2f}|{x.std() :.2f}")
agg = agg.drop(['best_val', 'best_iter', 'seed', 'total_loss'], axis=1)
agg
# Out:
# /tmp/ipykernel_12618/2104557232.py:41: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                           aipw_curve_bias aipw_curve_rmse gps_ratio_loss  \
# part  dataset dir
# test  ihdp-N  aipw         -0.30|0.24      0.46|0.25       0.34|0.00
#               c_ratio      -0.40|0.22      0.57|0.23       0.83|0.03
#               drnet        -0.20|0.10      0.38|0.09       nan|nan
#               drnet_tr     -0.20|0.10      0.38|0.09       nan|nan
#               erm          -0.15|0.24      0.34|0.20       nan|nan
#               ipw          -0.37|0.08      1.02|0.07       0.34|0.00
#               non_poisson  0.01|0.02       0.04|0.02       0.34|0.00
#               plugin       -0.30|0.24      0.46|0.25       nan|nan
#               poisson      -0.00|0.01      0.03|0.01       0.34|0.00
#               tresnet      -0.23|0.26      0.40|0.24       0.34|0.00
#       news-N  aipw         -0.01|0.03      0.02|0.02       nan|nan
#               drnet        -0.02|0.03      0.03|0.02       nan|nan
#               drnet_tr     -0.02|0.03      0.03|0.02       nan|nan
#               ipw          -0.02|0.03      0.03|0.02       nan|nan
#               mlp          -0.03|0.03      0.03|0.02       nan|nan
#               plugin       -0.01|0.03      0.02|0.02       nan|nan
#               tresnet      -0.01|0.03      0.03|0.02       nan|nan
#       news-N2 aipw         -0.00|0.03      0.03|0.02       0.35|0.00
#               c_ratio      -0.00|0.03      0.03|0.01       0.75|0.02
#               drnet        -0.02|0.02      0.03|0.02       nan|nan
#               drnet_tr     -0.02|0.03      0.03|0.02       0.35|0.00
#               erm          -0.00|0.03      0.03|0.02       nan|nan
#               drnet_tr     -0.02|0.01  0.02|0.01      4999.00|0.00
#               erm          -0.02|0.01  0.02|0.01      4999.00|0.00
#               ipw          -0.02|0.01  0.02|0.01      4999.00|0.00
#               non_poisson  -0.00|0.00  0.00|0.00      1999.00|0.00
#               plugin       -0.02|0.01  0.02|0.01      4999.00|0.00
#               poisson      -0.00|0.00  0.00|0.00      1999.00|0.00
#               tresnet      -0.02|0.01  0.02|0.01      4999.00|0.00
#       sim-B   aipw         0.12|1.17   1.98|0.52      1999.00|0.00
#               drnet        0.12|1.16   1.98|0.51      1999.00|0.00
#               drnet_tr     0.12|1.16   1.98|0.51      1999.00|0.00
#               ipw          0.12|1.16   1.98|0.51      1999.00|0.00
#               mlp          0.12|1.17   1.98|0.52      1999.00|0.00
#               mlp_tr       0.11|1.21   2.00|0.54      1999.00|0.00
#               plugin       0.12|1.16   1.98|0.51      1999.00|0.00
#               tresnet      0.12|1.17   1.98|0.52      1999.00|0.00
#       sim-N   aipw         0.10|0.02   0.11|0.03      4279.00|1287.70
#               c_ratio      -0.08|0.03  0.11|0.02      4999.00|0.00
#               drnet        0.10|0.02   0.11|0.03      4999.00|0.00
#               drnet_tr     0.10|0.02   0.11|0.03      4279.00|1287.70
#               erm          0.10|0.02   0.11|0.03      4999.00|0.00
#               ipw          0.10|0.02   0.11|0.03      4279.00|1287.70
#               mlp          0.10|0.03   0.11|0.03      1999.00|0.00
#               mlp_tr       0.10|0.03   0.11|0.03      1999.00|0.00
#               non_poisson  0.09|0.03   0.10|0.04      1999.00|0.00
#               plugin       0.10|0.02   0.11|0.03      4279.00|1287.70
#               poisson      0.09|0.03   0.10|0.04      1999.00|0.00
#               tresnet      0.10|0.02   0.11|0.03      4279.00|1287.70
#
#                           outcome_loss plugin_curve_rmse pluglin_curve_bias  \
# part  dataset dir
# test  ihdp-N  aipw         0.43|0.06    0.46|0.25         -0.30|0.24
#               c_ratio      0.25|0.04    0.58|0.23         -0.40|0.22
#               drnet        3.40|0.27    0.34|0.06         -0.20|0.10
#               drnet_tr     3.40|0.27    0.34|0.06         -0.20|0.10
#               erm          0.32|0.06    0.34|0.20         -0.15|0.24
#               ipw          8.55|0.69    0.93|0.08         -0.37|0.08
#               non_poisson  0.07|0.02    0.04|0.02         0.01|0.02
#               plugin       0.44|0.07    0.47|0.25         -0.30|0.24
#               poisson      0.90|0.02    0.03|0.01         -0.00|0.01
#               tresnet      0.31|0.05    0.40|0.24         -0.23|0.26
#       news-N  aipw         0.66|0.08    0.04|0.03         -0.01|0.03
#               drnet        1.10|0.08    0.06|0.02         -0.02|0.03
#               drnet_tr     1.08|0.09    0.06|0.03         -0.02|0.03
#               ipw          1.47|0.13    0.14|0.06         -0.02|0.03
#               mlp          1.31|0.11    0.17|0.03         -0.03|0.03
#               plugin       0.65|0.07    0.04|0.03         -0.01|0.03
#               tresnet      0.53|0.08    0.05|0.04         -0.01|0.03
#       news-N2 aipw         0.21|0.03    0.03|0.01         -0.00|0.03
#               c_ratio      0.10|0.03    0.03|0.01         -0.00|0.03
#               drnet        0.78|0.08    0.03|0.01         -0.02|0.02
#               drnet_tr     0.79|0.08    0.03|0.01         -0.02|0.03
#               erm          0.10|0.03    0.03|0.02         -0.00|0.03
#               ipw          1.46|0.14    0.14|0.02         -0.02|0.03
#               non_poisson  0.04|0.01    0.01|0.01         0.00|0.00
#               plugin       0.21|0.03    0.03|0.01         -0.00|0.03
#               poisson      0.97|0.01    0.00|0.00         0.00|0.00
#               tresnet      0.10|0.03    0.03|0.02         -0.00|0.03
#       sim-B   aipw         0.39|0.09    2.16|0.71         0.31|1.53
#               drnet        4.30|1.64    2.12|0.70         0.06|1.50
#               drnet_tr     4.27|1.63    2.16|0.71         0.05|1.52
#               ipw          8.07|3.56    1.64|0.35         0.11|1.16
#               mlp          5.28|1.97    1.88|0.43         0.14|1.16
#               mlp_tr       1.76|1.07    1.92|0.43         0.19|1.18
#               plugin       0.39|0.09    2.16|0.71         0.31|1.52
#               tresnet      0.35|0.07    2.14|0.68         0.29|1.50
#       sim-N   aipw         0.31|0.03    0.07|0.04         0.05|0.06
#               c_ratio      0.26|0.02    0.08|0.04         0.06|0.06
#               drnet        0.41|0.03    0.10|0.04         0.07|0.06
#               drnet_tr     0.41|0.03    0.09|0.04         0.07|0.06
#               erm          0.27|0.02    0.07|0.04         0.04|0.07
#               ipw          0.74|0.06    0.13|0.04         0.10|0.06
#               mlp          0.71|0.05    0.11|0.04         0.11|0.06
#               mlp_tr       0.71|0.05    0.11|0.04         0.11|0.06
#               non_poisson  0.35|0.10    0.07|0.04         0.05|0.06
#               plugin       0.31|0.03    0.08|0.04         0.05|0.06
#               poisson      0.88|0.04    0.07|0.04         0.04|0.06
#               tresnet      0.28|0.03    0.07|0.04         0.04|0.06
# train ihdp-N  aipw         0.43|0.06    0.44|0.25         -0.30|0.23
#               c_ratio      0.25|0.04    0.56|0.22         -0.39|0.19
#               drnet        3.40|0.27    0.32|0.03         -0.20|0.05
#               drnet_tr     3.40|0.27    0.32|0.03         -0.20|0.05
#               erm          0.32|0.06    0.30|0.20         -0.15|0.22
#               ipw          8.55|0.69    0.93|0.06         -0.37|0.06
#               non_poisson  0.07|0.02    0.03|0.01         0.01|0.02
#               plugin       0.44|0.07    0.44|0.25         -0.30|0.23
#               poisson      0.90|0.02    0.02|0.01         -0.00|0.01
#               tresnet      0.31|0.05    0.36|0.24         -0.23|0.23
#       news-N  aipw         0.66|0.08    0.04|0.02         -0.01|0.01
#               drnet        1.10|0.08    0.05|0.01         -0.02|0.01
#               drnet_tr     1.08|0.09    0.06|0.01         -0.02|0.01
#               ipw          1.47|0.13    0.13|0.07         -0.02|0.01
#               mlp          1.31|0.11    0.17|0.02         -0.03|0.01
#               plugin       0.65|0.07    0.03|0.02         -0.01|0.01
#               tresnet      0.53|0.08    0.05|0.04         -0.01|0.01
#       news-N2 aipw         0.21|0.03    0.01|0.01         -0.00|0.01
#               c_ratio      0.10|0.03    0.01|0.01         0.00|0.01
#               drnet        0.78|0.08    0.02|0.00         -0.02|0.01
#               drnet_tr     0.79|0.08    0.02|0.00         -0.02|0.01
#               erm          0.10|0.03    0.02|0.01         -0.00|0.01
#               ipw          1.46|0.14    0.13|0.02         -0.02|0.01
#               non_poisson  0.04|0.01    0.01|0.01         0.00|0.00
#               plugin       0.21|0.03    0.01|0.01         -0.00|0.01
#               poisson      0.97|0.01    0.00|0.00         0.00|0.00
#               tresnet      0.10|0.03    0.02|0.01         -0.00|0.01
#       sim-B   aipw         0.39|0.09    2.13|0.71         0.32|1.52
#               drnet        4.30|1.64    2.10|0.70         0.07|1.50
#               drnet_tr     4.27|1.63    2.13|0.72         0.06|1.52
#               ipw          8.07|3.56    1.61|0.33         0.12|1.16
#               mlp          5.28|1.97    1.85|0.42         0.15|1.16
#               mlp_tr       1.76|1.07    1.89|0.42         0.20|1.17
#               plugin       0.39|0.09    2.13|0.70         0.32|1.51
#               tresnet      0.35|0.07    2.11|0.68         0.30|1.49
#       sim-N   aipw         0.31|0.03    0.06|0.03         0.05|0.03
#               c_ratio      0.26|0.02    0.06|0.03         0.05|0.03
#               drnet        0.41|0.03    0.09|0.02         0.07|0.02
#               drnet_tr     0.41|0.03    0.08|0.02         0.07|0.02
#               erm          0.27|0.02    0.05|0.03         0.04|0.04
#               ipw          0.74|0.06    0.12|0.03         0.10|0.02
#               mlp          0.71|0.05    0.10|0.02         0.10|0.03
#               mlp_tr       0.71|0.05    0.11|0.02         0.10|0.03
#               non_poisson  0.35|0.10    0.05|0.03         0.04|0.04
#               plugin       0.31|0.03    0.06|0.03         0.05|0.03
#               poisson      0.88|0.04    0.05|0.03         0.04|0.04
#               tresnet      0.28|0.03    0.05|0.03         0.03|0.04
#
#                           tr_curve_bias tr_curve_rmse      tr_loss  \
# part  dataset dir
# test  ihdp-N  aipw         -0.30|0.24    0.46|0.25     4.05|0.58
#               c_ratio      -0.40|0.22    0.58|0.23     2.50|0.41
#               drnet        -0.20|0.10    0.38|0.09     20.81|1.25
#               drnet_tr     -0.20|0.10    0.38|0.09     20.81|1.25
#               erm          -0.15|0.24    0.33|0.20     2.61|0.43
#               ipw          -0.37|0.08    1.02|0.07     39.98|2.23
#               non_poisson  0.01|0.02     0.04|0.02     0.31|0.08
#               plugin       -0.30|0.24    0.47|0.25     4.16|0.64
#               poisson      -0.00|0.01    0.03|0.01     9.76|0.05
#               tresnet      -0.23|0.26    0.40|0.24     2.55|0.36
#       news-N  aipw         -0.01|0.03    0.04|0.03     3.41|0.25
#               drnet        -0.02|0.03    0.03|0.02     3.74|0.15
#               drnet_tr     -0.02|0.03    0.03|0.02     3.72|0.14
#               ipw          -0.02|0.03    0.03|0.02     4.15|0.18
#               mlp          -0.03|0.03    0.03|0.02     4.05|0.17
#               plugin       -0.01|0.03    0.04|0.03     3.41|0.25
#               tresnet      -0.01|0.03    0.05|0.05     2.22|0.38
#       news-N2 aipw         -0.00|0.03    0.03|0.01     2.15|0.36
#               c_ratio      -0.00|0.03    0.03|0.02     1.02|0.31
#               drnet        -0.02|0.02    0.03|0.02     3.58|0.15
#               drnet_tr     -0.02|0.03    0.03|0.02     3.58|0.14
#               erm          -0.00|0.03    0.03|0.02     0.87|0.30
#               ipw          -0.02|0.03    0.03|0.02     4.04|0.17
#               non_poisson  0.00|0.00     0.01|0.01     0.07|0.02
#               plugin       -0.00|0.03    0.03|0.01     2.14|0.34
#               poisson      0.00|0.00     0.00|0.00     9.99|0.01
#               tresnet      -0.00|0.03    0.03|0.02     0.90|0.35
#       sim-B   aipw         0.31|1.53     2.17|0.71     3.66|0.61
#               drnet        0.06|1.50     2.15|0.71     41.60|15.97
#               drnet_tr     0.05|1.52     2.18|0.71     41.31|15.92
#               ipw          0.11|1.16     2.00|0.52     61.86|25.71
#               mlp          0.14|1.16     1.98|0.53     46.36|18.04
#               mlp_tr       0.19|1.18     1.96|0.48     15.60|10.99
#               plugin       0.31|1.52     2.16|0.71     3.67|0.61
#               tresnet      0.29|1.50     2.15|0.69     3.21|0.45
#       sim-N   aipw         0.05|0.06     0.08|0.04     3.16|0.28
#               c_ratio      0.06|0.06     0.08|0.04     2.66|0.20
#               drnet        0.07|0.06     0.10|0.04     4.05|0.33
#               drnet_tr     0.07|0.06     0.10|0.04     4.03|0.33
#               erm          0.04|0.07     0.08|0.05     2.69|0.21
#               ipw          0.10|0.06     0.12|0.05     5.73|0.48
#               mlp          0.11|0.06     0.12|0.05     5.65|0.40
#               mlp_tr       0.11|0.06     0.12|0.05     5.60|0.40
#               non_poisson  0.05|0.06     0.07|0.04     3.74|1.16
#               plugin       0.05|0.06     0.08|0.04     3.15|0.28
#               poisson      0.04|0.06     0.08|0.04     8.75|0.42
#               tresnet      0.04|0.06     0.07|0.04     2.76|0.26
# train ihdp-N  aipw         -0.30|0.23    0.43|0.25     4.05|0.58
#               c_ratio      -0.39|0.19    0.56|0.22     2.50|0.41
#               drnet        -0.20|0.05    0.36|0.05     20.81|1.25
#               drnet_tr     -0.20|0.05    0.36|0.05     20.81|1.25
#               erm          -0.15|0.22    0.29|0.20     2.61|0.43
#               ipw          -0.37|0.06    1.01|0.04     39.98|2.23
#               non_poisson  0.01|0.02     0.04|0.01     0.31|0.08
#               plugin       -0.30|0.23    0.44|0.25     4.16|0.64
#               poisson      -0.00|0.01    0.02|0.01     9.76|0.05
#               tresnet      -0.23|0.23    0.36|0.25     2.55|0.36
#       news-N  aipw         -0.01|0.01    0.03|0.02     3.41|0.25
#               drnet        -0.02|0.01    0.02|0.01     3.74|0.15
#               drnet_tr     -0.02|0.01    0.02|0.01     3.72|0.14
#               ipw          -0.02|0.01    0.02|0.01     4.15|0.18
#               mlp          -0.03|0.01    0.03|0.01     4.05|0.17
#               plugin       -0.01|0.01    0.03|0.02     3.41|0.25
#               tresnet      -0.01|0.01    0.05|0.05     2.22|0.38
#       news-N2 aipw         -0.00|0.01    0.01|0.01     2.15|0.36
#               c_ratio      0.00|0.01     0.01|0.01     1.02|0.31
#               drnet        -0.02|0.01    0.02|0.01     3.58|0.15
#               drnet_tr     -0.02|0.01    0.02|0.01     3.58|0.14
#               erm          -0.00|0.01    0.02|0.01     0.87|0.30
#               ipw          -0.02|0.01    0.02|0.01     4.04|0.17
#               non_poisson  0.00|0.00     0.01|0.01     0.07|0.02
#               plugin       -0.00|0.01    0.01|0.01     2.14|0.34
#               poisson      0.00|0.00     0.00|0.00     9.99|0.01
#               tresnet      -0.00|0.01    0.02|0.01     0.90|0.35
#       sim-B   aipw         0.32|1.52     2.14|0.71     3.66|0.61
#               drnet        0.07|1.50     2.13|0.71     41.60|15.97
#               drnet_tr     0.06|1.52     2.15|0.72     41.31|15.92
#               ipw          0.12|1.16     1.97|0.51     61.86|25.71
#               mlp          0.15|1.16     1.96|0.53     46.36|18.04
#               mlp_tr       0.20|1.17     1.93|0.47     15.60|10.99
#               plugin       0.32|1.51     2.14|0.71     3.67|0.61
#               tresnet      0.30|1.49     2.12|0.68     3.21|0.45
#       sim-N   aipw         0.05|0.03     0.06|0.03     3.16|0.28
#               c_ratio      0.05|0.03     0.06|0.03     2.66|0.20
#               drnet        0.07|0.02     0.09|0.02     4.05|0.33
#               drnet_tr     0.07|0.02     0.09|0.02     4.03|0.33
#               erm          0.04|0.04     0.06|0.03     2.69|0.21
#               ipw          0.10|0.02     0.11|0.03     5.73|0.48
#               mlp          0.10|0.03     0.11|0.03     5.65|0.40
#               mlp_tr       0.10|0.03     0.11|0.03     5.60|0.40
#               non_poisson  0.04|0.04     0.05|0.04     3.74|1.16
#               plugin       0.05|0.03     0.06|0.03     3.15|0.28
#               poisson      0.04|0.04     0.05|0.03     8.75|0.42
#               tresnet      0.03|0.04     0.05|0.03     2.76|0.26
#
#                           density_negll
# part  dataset dir
# test  ihdp-N  aipw         nan|nan
#               c_ratio      nan|nan
#               drnet        nan|nan
#               drnet_tr     nan|nan
#               erm          3.32|0.05
#               ipw          nan|nan
#               non_poisson  nan|nan
#               plugin       nan|nan
#               poisson      nan|nan
#               tresnet      nan|nan
#       news-N  aipw         3.43|0.00
#               drnet        nan|nan
#               drnet_tr     3.43|0.00
#               ipw          3.43|0.00
#               mlp          3.43|0.00
#               plugin       nan|nan
#               tresnet      3.43|0.00
#       news-N2 aipw         nan|nan
#               c_ratio      nan|nan
#               drnet        nan|nan
#               drnet_tr     nan|nan
#               erm          3.43|0.00
#               ipw          nan|nan
#               non_poisson  nan|nan
#               plugin       nan|nan
#               poisson      nan|nan
#               tresnet      nan|nan
#       sim-B   aipw         3.43|0.00
#               drnet        nan|nan
#               drnet_tr     3.43|0.00
#               ipw          3.43|0.00
#               mlp          3.43|0.01
#               mlp_tr       3.41|0.02
#               plugin       nan|nan
#               tresnet      3.42|0.01
#       sim-N   aipw         3.43|0.00
#               c_ratio      nan|nan
#               drnet        nan|nan
#               drnet_tr     3.43|0.00
#               erm          3.43|0.00
#               ipw          3.43|0.00
#               mlp          3.43|0.00
#               mlp_tr       3.43|0.00
#               non_poisson  nan|nan
#               plugin       nan|nan
#               poisson      nan|nan
#               tresnet      3.43|0.00
# train ihdp-N  aipw         nan|nan
#               c_ratio      nan|nan
#               drnet        nan|nan
#               drnet_tr     nan|nan
#               erm          3.32|0.05
#               ipw          nan|nan
#               non_poisson  nan|nan
#               plugin       nan|nan
#               poisson      nan|nan
#               tresnet      nan|nan
#       news-N  aipw         3.43|0.00
#               drnet        nan|nan
#               drnet_tr     3.43|0.00
#               ipw          3.43|0.00
#               mlp          3.43|0.00
#               plugin       nan|nan
#               tresnet      3.43|0.00
#       news-N2 aipw         nan|nan
#               c_ratio      nan|nan
#               drnet        nan|nan
#               drnet_tr     nan|nan
#               erm          3.43|0.00
#               ipw          nan|nan
#               non_poisson  nan|nan
#               plugin       nan|nan
#               poisson      nan|nan
#               tresnet      nan|nan
#       sim-B   aipw         3.43|0.00
#               drnet        nan|nan
#               drnet_tr     3.43|0.00
#               ipw          3.43|0.00
#               mlp          3.43|0.01
#               mlp_tr       3.41|0.02
#               plugin       nan|nan
#               tresnet      3.42|0.01
#       sim-N   aipw         3.43|0.00
#               c_ratio      nan|nan
#               drnet        nan|nan
#               drnet_tr     3.43|0.00
#               erm          3.43|0.00
#               ipw          3.43|0.00
#               mlp          3.43|0.00
#               mlp_tr       3.43|0.00
#               non_poisson  nan|nan
#               plugin       nan|nan
#               poisson      nan|nan
#               tresnet      3.43|0.00

# %% [markdown]
# Plot curves

# %%
# curves_means = curves.groupby(['dataset', 'var', 'ratio', 'delta']).mean().reset_index().set_index(['dataset', 'var', 'ratio'])
# curves_stdevs = curves.groupby(['dataset', 'var', 'ratio', 'delta']).std().reset_index().set_index(['dataset', 'var', 'ratio'])
# # D_var0_ratio0 = curves[curves.combo == 0]
# curves_means

# %%
curves.dataset.unique()
# curves
# Out:
# array(['ihdp-N', 'sim-N', 'news-N'], dtype=object)

# %%
# os.makedirs("benchmark_plots", exist_ok=True)
# for part in ("train", "test"):
#     for dset in datasets:
#         print(f"========== {dset}-{part} =========")
#         ipw = curves[curves.ipw == ]
#         D = curves[(curves.dataset == dset)].drop_duplicates(["delta", "dir", "seed"])
#         D = D.fillna(0)
#         truth = D[D.dir == D.dir.iloc[0]][["delta", f"{part}_truth"]]=≠
#         print(D.shape)
#         sns.lineplot(x="delta", y=f"{part}_tr_estim", hue="dir", data=D, legend=True)
#         # sns.lineplot(x="delta", y=f"{part}_aipw_estim", hue="dir", data=D, legend=True, ls="--")
#         sns.lineplot(x="delta", y=f"{part}_truth", label="truth", c="black", ls=":", data=D, legend=True)
#         plt.legend(loc='upper left',framealpha=0.5)
    
#         plt.show()
